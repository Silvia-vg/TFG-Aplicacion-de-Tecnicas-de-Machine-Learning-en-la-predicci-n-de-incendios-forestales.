# %%
# Librerías
import pandas as pd
import numpy as np
import datetime
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

import tensorflow as tf 
from tensorflow import keras

# %%
import random

np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %%
#Leemos el archivo excel

df=pd.read_excel("corregido_open-meteo-37.08N6.42W2m.xlsx", header=0)
# Definimos la lista de incendios (Inicio, Fin)

incendios_info = [
    ("2017-06-12 14:00", "2017-06-13 23:59"),
    ("2017-06-24 21:00", "2017-07-04 23:59"),
    ("2019-05-13 14:00", "2019-05-15 23:59"),
    ("2019-06-01 14:00", "2019-06-06 23:59"),
    ("2019-06-07 15:00", "2019-06-07 23:59"),
    ("2019-08-27 10:00", "2019-08-27 23:59"),
    ("2019-09-12 14:00", "2019-09-15 23:59"),
    ("2021-07-24 14:00", "2021-07-28 23:59"),
    ("2021-08-17 14:00", "2021-08-19 23:59"),
    ("2022-07-25 15:00", "2022-07-28 23:59"),
    ("2022-07-25 16:00", "2022-07-28 23:59"), # Nota: Este solapa con el anterior
    ("2023-08-05 14:00", "2023-08-09 23:59")
]

# Inicializamos la columna "incendio" a "no"

df["incendio"] = 0

# Iteramos por cada incendio y marcamos las filas correspondientes
for inicio, fin in incendios_info:
    condicion = (df["time"] >= pd.to_datetime(inicio)) & (df["time"] <= pd.to_datetime(fin))
    df.loc[condicion, "incendio"] = 1

df=df.dropna(axis=0)
print(df)
# Out:
#                      time  temperature_2m (°C)  relative_humidity_2m (%)  \
# 0     2017-01-01 00:00:00                  6.5                        95
# 1     2017-01-01 01:00:00                  5.7                        96
# 2     2017-01-01 02:00:00                  5.0                        98
# 3     2017-01-01 03:00:00                  4.8                        98
# 4     2017-01-01 04:00:00                  4.7                        98
# ...                   ...                  ...                       ...
# 70123 2024-12-31 19:00:00                  9.4                        77
# 70124 2024-12-31 20:00:00                  8.0                        83
# 70125 2024-12-31 21:00:00                  7.4                        87
# 70126 2024-12-31 22:00:00                  6.6                        88
# 70127 2024-12-31 23:00:00                  5.9                        89
#
#        surface_pressure (hPa)  wind_speed_10m (km/h)  wind_direction_10m (°)  \
# 0                      1028.9                    5.4                      37
# 1                      1028.1                    6.0                      33
# 2                      1027.7                    4.8                      13
# 3                      1027.6                    7.9                      16
# 4                      1027.2                   10.0                      30
# ...                       ...                    ...                     ...
# 70123                  1026.8                    4.8                      45
# 70124                  1027.0                    5.5                      36
# 70125                  1027.6                    7.8                      29
# 70126                  1027.8                    6.7                      46
# 70127                  1028.2                    6.1                      43
#
#        wind_speed_100m (km/h)  wind_direction_100m (°)  wind_gusts_10m (km/h)  \
# 0                        10.3                      126                    6.8
# 1                        10.8                      116                    8.3
# 2                         8.4                       80                    8.6
# 3                        11.7                       43                   13.0
# 4                        19.6                       32                   16.9
# ...                       ...                      ...                    ...
# 70123                    14.1                       71                    8.3
# 70124                    12.3                       75                    6.8
# 70125                    17.7                       48                   11.9
# 70126                    18.5                       58                   12.2
# 70127                    16.9                       56                    9.0
#
#        incendio
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 70123         0
# 70124         0
# 70125         0
# 70126         0
# 70127         0
#
# [70128 rows x 10 columns]

# %%
# Contamos los missing values
df.isnull().sum()
# Out:
# time                        0
# temperature_2m (°C)         0
# relative_humidity_2m (%)    0
# surface_pressure (hPa)      0
# wind_speed_10m (km/h)       0
# wind_direction_10m (°)      0
# wind_speed_100m (km/h)      0
# wind_direction_100m (°)     0
# wind_gusts_10m (km/h)       0
# incendio                    0
# dtype: int64

# %% [markdown]
# Eliminamos las primeras filas porque contienen la información de la localización y no nos interesa para entrenar los datos. También quitamos los valores faltantes.

# %%
df=df.dropna(axis=0) #axis=0 elimina filas, axis=1 columnas donde valores ausentes en algunas filas

# %% [markdown]
# Ya hemos limpiado los datos de valores faltantes, ahora vamos a ver si hay outliers.

# %%
df.describe()
# Out:
#                       time  temperature_2m (°C)  relative_humidity_2m (%)  \
# count                70128         70128.000000              70128.000000
# mean   2020-12-31 23:30:00            18.543586                 67.785150
# min    2017-01-01 00:00:00            -1.900000                  4.000000
# 25%    2019-01-01 11:45:00            13.300000                 51.000000
# 50%    2020-12-31 23:30:00            18.100000                 70.000000
# 75%    2023-01-01 11:15:00            23.300000                 87.000000
# max    2024-12-31 23:00:00            44.400000                100.000000
# std                    NaN             7.320375                 21.853003
#
#        surface_pressure (hPa)  wind_speed_10m (km/h)  wind_direction_10m (°)  \
# count            70128.000000           70128.000000            70128.000000
# mean              1017.403385              10.258887              191.826474
# min                986.200000               0.000000                1.000000
# 25%               1013.700000               6.600000               72.000000
# 50%               1016.500000               9.100000              229.000000
# 75%               1021.000000              13.100000              270.000000
# max               1038.200000              47.900000              360.000000
# std                  5.726889               5.377497              106.333515
#
#        wind_speed_100m (km/h)  wind_direction_100m (°)  wind_gusts_10m (km/h)  \
# count            70128.000000             70128.000000           70128.000000
# mean                17.257692               192.485598              21.659895
# min                  0.000000                 1.000000               1.400000
# 25%                 10.900000                77.000000              12.600000
# 50%                 17.100000               227.000000              19.100000
# 75%                 22.500000               268.000000              28.400000
# max                 76.400000               360.000000             108.400000
# std                  8.594099               103.748582              11.253618
#
#            incendio
# count  70128.000000
# mean       0.013133
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
# std        0.113846

# %%
#Creamos los vectores X e Y

#Dividimos los datos en datos de entrenamiento y de prueba
# Definimos la fecha de corte
fecha_corte = pd.to_datetime('2022-07-01')

# Creamos máscaras para no modificar el dataframe original
es_train = pd.to_datetime(df['time']) < fecha_corte
es_test = pd.to_datetime(df['time']) >= fecha_corte

# Creamos X e Y filtrando y soltando columnas solo para el modelo
X_train = df[es_train].drop(columns=['time', 'incendio'])
Y_train = df.loc[es_train, 'incendio']

original_column_names = list(X_train.columns)

X_test = df[es_test].drop(columns=['time', 'incendio'])
Y_test = df.loc[es_test, 'incendio']
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = keras.models.Sequential()
model.add(keras.Input(shape=(X_train.shape[1],)))
model.add(keras.layers.Dense(32, activation="relu")) #Antes 16, 32
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(16, activation="relu")) # 8, 16
model.add(keras.layers.Dropout(0.3))
#model.add(keras.layers.Dense(8, activation="relu"))  #Nueva capa 8
model.add(keras.layers.Dense(1, activation="sigmoid")) #1 porque solo hay una clase y sigmoid porque se trata de clas. binaria

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",  # para clasificación binaria
    metrics=["recall"]
)
# Early Stopping para no entrenar épocas en vano
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
from sklearn.utils import class_weight

#Reducción de Dimensionalidad (PCA)
pca = PCA(n_components=0.95)

# Calcula los pesos automáticamente
weights = class_weight.compute_class_weight('balanced', 
                                            classes=np.unique(Y_train), 
                                            y=Y_train)
dict_weights = dict(enumerate(weights))


history = model.fit(
    X_train, Y_train,
    epochs=20,
    batch_size=32,
    validation_split=0.2,  # valida 20% de train
    verbose=2,
    class_weight=dict_weights,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/20
# 1205/1205 - 14s - 11ms/step - loss: 0.5538 - recall: 0.7123 - val_loss: 0.5385 - val_recall: 0.8841
# Epoch 2/20
# 1205/1205 - 8s - 6ms/step - loss: 0.4896 - recall: 0.8421 - val_loss: 0.5149 - val_recall: 0.8780
# Epoch 3/20
# 1205/1205 - 8s - 7ms/step - loss: 0.4555 - recall: 0.8614 - val_loss: 0.5127 - val_recall: 0.8293
# Epoch 4/20
# 1205/1205 - 10s - 8ms/step - loss: 0.4395 - recall: 0.8509 - val_loss: 0.4813 - val_recall: 0.7622
# Epoch 5/20
# 1205/1205 - 9s - 8ms/step - loss: 0.4301 - recall: 0.9035 - val_loss: 0.4924 - val_recall: 0.7012
# Epoch 6/20
# 1205/1205 - 10s - 8ms/step - loss: 0.4241 - recall: 0.8930 - val_loss: 0.5075 - val_recall: 0.7256
# Epoch 7/20
# 1205/1205 - 9s - 7ms/step - loss: 0.4173 - recall: 0.8895 - val_loss: 0.5040 - val_recall: 0.6768
# Epoch 8/20
# 1205/1205 - 10s - 8ms/step - loss: 0.4208 - recall: 0.8702 - val_loss: 0.5156 - val_recall: 0.6829
# Epoch 9/20
# 1205/1205 - 8s - 7ms/step - loss: 0.4009 - recall: 0.9140 - val_loss: 0.4668 - val_recall: 0.6098
# Epoch 10/20
# 1205/1205 - 9s - 8ms/step - loss: 0.4042 - recall: 0.8930 - val_loss: 0.4682 - val_recall: 0.5793
# Epoch 11/20
# 1205/1205 - 8s - 7ms/step - loss: 0.3964 - recall: 0.8842 - val_loss: 0.4753 - val_recall: 0.6159
# Epoch 12/20
# 1205/1205 - 9s - 8ms/step - loss: 0.3901 - recall: 0.8965 - val_loss: 0.4852 - val_recall: 0.5915
# Epoch 13/20
# 1205/1205 - 8s - 7ms/step - loss: 0.3900 - recall: 0.9035 - val_loss: 0.4665 - val_recall: 0.5732
# Epoch 14/20
# 1205/1205 - 9s - 8ms/step - loss: 0.3936 - recall: 0.8860 - val_loss: 0.4928 - val_recall: 0.6098
# Epoch 15/20
# 1205/1205 - 10s - 8ms/step - loss: 0.3875 - recall: 0.8947 - val_loss: 0.4738 - val_recall: 0.6341
# Epoch 16/20
# 1205/1205 - 8s - 7ms/step - loss: 0.3884 - recall: 0.9070 - val_loss: 0.4666 - val_recall: 0.6341
# Epoch 17/20
# 1205/1205 - 9s - 7ms/step - loss: 0.3888 - recall: 0.8965 - val_loss: 0.4835 - val_recall: 0.6280
# Epoch 18/20
# 1205/1205 - 9s - 8ms/step - loss: 0.3849 - recall: 0.9018 - val_loss: 0.4813 - val_recall: 0.6402

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")
# Out:
# Loss: 0.4442, Accuracy: 0.5348

# %%
from sklearn.metrics import f1_score

Y_pred = (model.predict(X_test) > 0.5).astype(int)

# Calcular F1 score
score = f1_score(Y_test, Y_pred)
print("F1 Score:", score)
# Out:
# 687/687 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# F1 Score: 0.033921302578018994

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, Y_pred)
print(cm)
# Out:
# [[16164  5609]
#  [   87   100]]

# %%
pip install scikeras
# Out:
# Requirement already satisfied: scikeras in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikeras) (3.11.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikeras) (1.7.2)
# Requirement already satisfied: absl-py in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.3)
# Requirement already satisfied: rich in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (14.2.0)
# Requirement already satisfied: namex in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (0.18.0)
# Requirement already satisfied: ml-dtypes in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
# Definimos una función que crea el modelo (necesaria para el wrapper)
from tensorflow import keras
from tensorflow.keras import layers

def create_model(hidden_layers=1, neurons=32, dropout_rate=0.0, meta=None):
    tf.random.set_seed(42) 
    model = keras.models.Sequential()
    
    input_dim = meta["n_features_in_"]
    model.add(keras.Input(shape=(input_dim,)))
    
    for _ in range(hidden_layers):
        model.add(layers.Dense(neurons, activation="relu"))
        if dropout_rate > 0:
            model.add(layers.Dropout(dropout_rate, seed=42))
    
    model.add(layers.Dense(1, activation="sigmoid"))
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0005),
        loss="binary_crossentropy",
        metrics=[tf.keras.metrics.Recall(name="recall")]
    )
    
    return model

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',           # <--- CAMBIA ESTO (de val_loss a loss)
    patience=5, 
    restore_best_weights=True # Muy importante para quedarse con el mejor punto
)
# Creamos el objeto estimador
model_wrapper = KerasClassifier(
    model=create_model,
    verbose=0,
    callbacks=[early_stop]
)

# %%
print(model_wrapper.get_params().keys())
# Out:
# dict_keys(['model', 'build_fn', 'warm_start', 'random_state', 'optimizer', 'loss', 'metrics', 'batch_size', 'validation_batch_size', 'verbose', 'callbacks', 'validation_split', 'shuffle', 'run_eagerly', 'epochs', 'class_weight'])

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, StratifiedKFold

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('pca', PCA(n_components=0.95)),
    ('mlp', model_wrapper)
])
# Definimos qué queremos probar 
param_grid = {'pca__n_components':[0.9, 0.95],
              'mlp__model__hidden_layers': [1, 2], # Probar con 1 o 2 capas ocultas 
              'mlp__model__neurons': [16, 32], # Probar diferentes anchos 16, 32
              'mlp__batch_size': [16, 32], # Probar diferentes tamaños de lote 16,32 
              'mlp__model__dropout_rate': [0.0, 0.1],
              'mlp__epochs': [20]
             } 
from sklearn.model_selection import GridSearchCV 
# Configuramos la búsqueda aleatoria 
grid_search = GridSearchCV( estimator= pipeline, 
                           param_grid=param_grid, 
                           cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
                           scoring='f1', # Optimizamos para Recall como querías 
                           verbose=2,
                           n_jobs=1
                          ) # Ejecutar búsqueda (usa class_weight si tu dataset sigue desbalanceado) 
grid_result = grid_search.fit(X_train, Y_train, 
                              mlp__class_weight=dict_weights,
                              mlp__validation_split=0.2) 
# 4. Ver resultados del mejor modelo print(f"Mejor Recall: {grid_result.best_score_}") 
print(f"Mejores parámetros: {grid_result.best_params_}")
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time= 2.4min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time=  49.6s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time=  22.9s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time=  21.9s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time=  51.5s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.1min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.1min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.1min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time=  36.2s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time=  39.1s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time=  39.4s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time=  46.7s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time=  23.7s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.5min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.4min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.4min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.3min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.3min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.3min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.2min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.1min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time=  57.7s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time=  33.9s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.1min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.6min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 2.3min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.6min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time=  46.9s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 2.0min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.5min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.7min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time= 2.3min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 2.0min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.0min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 2.0min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 2.7min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.5min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time=  56.0s
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.5min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 2.6min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.3min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.9min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 2.5min
# [CV] END mlp__batch_size=16, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.7min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time=  26.2s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time=  54.4s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.1min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time=  42.5s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time=  41.0s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time=1217.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.6min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time=  32.8s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.4min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.4min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time=  36.9s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.6min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 2.5min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 2.7min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 2.6min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 2.8min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.0, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.9min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.1min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.4min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.4min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.9; total time=  24.6s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time=  58.1s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.2min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=1, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.1min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.9; total time= 1.1min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.4min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=16, pca__n_components=0.95; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.0min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.9; total time=  58.4s
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.4min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.3min
# [CV] END mlp__batch_size=32, mlp__epochs=20, mlp__model__dropout_rate=0.1, mlp__model__hidden_layers=2, mlp__model__neurons=32, pca__n_components=0.95; total time= 1.9min
# Mejores parámetros: {'mlp__batch_size': 16, 'mlp__epochs': 20, 'mlp__model__dropout_rate': 0.0, 'mlp__model__hidden_layers': 2, 'mlp__model__neurons': 32, 'pca__n_components': 0.95}

# %%
pip install scikeras
# Out:
# Requirement already satisfied: scikeras in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikeras) (3.11.2)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikeras) (1.7.2)
# Requirement already satisfied: absl-py in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.3)
# Requirement already satisfied: rich in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (14.2.0)
# Requirement already satisfied: namex in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (0.18.0)
# Requirement already satisfied: ml-dtypes in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from keras>=3.2.0->scikeras) (25.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\silvi\anaconda3\envs\tf\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import precision_recall_curve

# 🔹 1. Probabilidades (IMPORTANTÍSIMO)
# Probabilidades de clase positiva
y_prob = grid_result.best_estimator_.predict_proba(X_test)[:, 1]

# Curva Precision-Recall
precisions, recalls, thresholds = precision_recall_curve(Y_test, y_prob)

# Buscar threshold que mantenga Recall >= 0.90 y maximice Precision
target_recall = 0.5
idx = np.where(recalls >= target_recall)[0]  # todos los thresholds con Recall >= 0.9
best_idx = idx[np.argmax(precisions[idx])]    # entre ellos, escoger el que da mayor Precision
best_threshold = thresholds[best_idx]

print("Threshold óptimo:", best_threshold)
print("Precision:", precisions[best_idx])
print("Recall:", recalls[best_idx])

# Aplicar threshold
Y_pred = (y_prob >= 0.5).astype(int)
threshold=0.5
# Matriz de confusión final
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, Y_pred)
print(cm)
# 🔹 5. Visualización
import seaborn as sns
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicción")
plt.ylabel("Valor real")
plt.title(f"Matriz de confusión (umbral={threshold})")
plt.show()
# Out:
# Threshold óptimo: 0.42434016
# Precision: 0.01984783327820046
# Recall: 0.6417112299465241
# [[16924  4849]
#  [   91    96]]

# %%
print(dict_weights)

# %%
print(np.mean(Y_train))
print(np.mean(Y_test))

# %% [markdown]
# Vemos que F1 Score es muy bajo ya que nuestro dataset está muy desbalanceado, por tanto, vamos a usar class weight para que la clase minoritaria(Incendio) tenga más peso.

# %%
from sklearn.metrics import precision_score, recall_score

Y_pred = (grid_result.best_estimator_.predict(X_test) > 0.1).astype(int)


print("Recall:", recall_score(Y_test, Y_pred))
print("Precision:", precision_score(Y_test, Y_pred))
print("F1 Score:", f1_score(Y_test, Y_pred))

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(Y_test, Y_pred)
print(cm)

y_prob = grid_result.best_estimator_.predict_proba(X_test)[:, 1]

print("Min:", y_prob.min())
print("Max:", y_prob.max())
print("Ejemplo:", y_prob[:10])
plt.hist(y_prob, bins=50)
plt.title("Distribución de probabilidades")
plt.show()
y_prob = grid_result.best_estimator_.predict_proba(X_test)[:, 1]

for t in [0.1, 0.2, 0.5, 0.6]:
    y_pred = (y_prob >= t).astype(int)
    tn, fp, fn, tp = confusion_matrix(Y_test, y_pred).ravel()
    
    print(f"\nThreshold {t}")
    print(f"FP: {fp}, FN: {fn}")

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# Probabilidades
y_prob = grid_result.best_estimator_.predict_proba(X_test)[:, 1]

# Curva Precision-Recall
precision, recall, thresholds = precision_recall_curve(Y_test, y_prob)

# 🔹 Calcular F1 para cada umbral
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-8)

# 🔹 Mejor umbral según F1
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]

print("Mejor threshold (F1):", best_threshold)
print("Precision:", precision[best_idx])
print("Recall:", recall[best_idx])
print("F1:", f1_scores[best_idx])

# 📈 Gráfica Precision-Recall
plt.figure()
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Curva Precision-Recall")

# Punto óptimo
plt.scatter(recall[best_idx], precision[best_idx])
plt.show()

# %%
# Queremos recall >= 0.90
target_recall = 0.90

idx = np.where(recall >= target_recall)[0][-1]
threshold_recall = thresholds[idx]

print("Threshold con recall >= 0.90:", threshold_recall)
print("Precision:", precision[idx])
print("Recall:", recall[idx])

# %%
# 1. Buscamos los índices (los números de la izquierda) que corresponden a esas fechas
mask_incendio = (df.iloc[:, 0] >= "2022-07-25 15:00") & (df.iloc[:, 0] <= "2022-07-28 23:59")
indices_incendio = df[mask_incendio].index

print(indices_incendio)
# 2. Creamos un DataFrame de resultados uniendo y_test e y_pred_opt
# Importante: X_test conserva el índice original (ej: 71, 72...)
df_resultados = pd.DataFrame({
    'real': Y_test,
    'prediccion': Y_pred
}, index=Y_test.index)

df_resultados
# 3. Filtramos df_resultados usando solo los índices que encontramos en el paso 1
# Esto selecciona solo las filas del incendio que cayeron en tu set de TEST
df_incendio_test = df_resultados.loc[df_resultados.index.isin(indices_incendio)]

df_incendio_test

# 4. Recuperamos las fechas para el eje X
df_incendio_test['fecha'] = df.loc[df_incendio_test.index, df.columns[0]]
df_incendio_test = df_incendio_test.sort_values('fecha')
 
df_incendio_test
# --- Visualización ---
plt.figure(figsize=(15, 6))

# --- REALIDAD: siempre abajo en rojo ---
plt.scatter(
    df_incendio_test['fecha'], 
    [0]*len(df_incendio_test),   # todos abajo
    color='red', 
    label='Realidad (Incendio real)', 
    s=80, 
    alpha=0.6
)

# --- PREDICCIONES ---
# Predicción = 1 (Incendio) -> cruces rojas arriba
pred_si = df_incendio_test[df_incendio_test['prediccion'] == 1]
plt.scatter(
    pred_si['fecha'], 
    [1]*len(pred_si), 
    color='red', 
    marker='x', 
    label='Predicción: Incendio', 
    s=80
)

# Predicción = 0 (No incendio) -> cruces azules a otra altura
pred_no = df_incendio_test[df_incendio_test['prediccion'] == 0]
plt.scatter(
    pred_no['fecha'], 
    [0.5]*len(pred_no),  # altura intermedia
    color='blue', 
    marker='x', 
    label='Predicción: No Incendio', 
    s=80
)

# Ejes y estilo
plt.yticks([0, 0.5, 1], ['Real', 'Pred No Incendio', 'Pred Incendio'])
plt.title('Comparativa Incendio 2022-07-25 15:00 hasta 2022-07-28 23:59')
plt.xlabel('Fecha y Hora')
plt.grid(True, axis='both', linestyle='--', alpha=0.3)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Finalmente, contamos cuantas horas de incendio predice bien

total_incendios_predichos = df_incendio_test['prediccion'].sum()

print(f'Se han detectado {total_incendios_predichos} horas del incendio de {len(df_incendio_test)} horas. ' )
# Out:
# Index([48759, 48760, 48761, 48762, 48763, 48764, 48765, 48766, 48767, 48768,
#        48769, 48770, 48771, 48772, 48773, 48774, 48775, 48776, 48777, 48778,
#        48779, 48780, 48781, 48782, 48783, 48784, 48785, 48786, 48787, 48788,
#        48789, 48790, 48791, 48792, 48793, 48794, 48795, 48796, 48797, 48798,
#        48799, 48800, 48801, 48802, 48803, 48804, 48805, 48806, 48807, 48808,
#        48809, 48810, 48811, 48812, 48813, 48814, 48815, 48816, 48817, 48818,
#        48819, 48820, 48821, 48822, 48823, 48824, 48825, 48826, 48827, 48828,
#        48829, 48830, 48831, 48832, 48833, 48834, 48835, 48836, 48837, 48838,
#        48839],
#       dtype='int64')
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\4205262520.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_incendio_test['fecha'] = df.loc[df_incendio_test.index, df.columns[0]]
# Se han detectado 45 horas del incendio de 81 horas.

# %%
from sklearn.inspection import permutation_importance

X_test_df = pd.DataFrame(X_test, columns=original_column_names)

result = permutation_importance(
    grid_search.best_estimator_, 
    X_test_df,
    Y_test,
    n_repeats=10,
    random_state=42,
    n_jobs=-1
)

importancia = pd.DataFrame({
    'Variable': original_column_names,
    'Importancia': result.importances_mean
}).sort_values(by='Importancia', ascending=False)

print(importancia)
# Out:
# C:\Users\silvi\anaconda3\envs\tf\lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
#                    Variable  Importancia
# 7     wind_gusts_10m (km/h)     0.017336
# 3     wind_speed_10m (km/h)     0.012086
# 5    wind_speed_100m (km/h)     0.005902
# 0       temperature_2m (°C)     0.000269
# 6   wind_direction_100m (°)    -0.002951
# 1  relative_humidity_2m (%)    -0.006489
# 4    wind_direction_10m (°)    -0.007919
# 2    surface_pressure (hPa)    -0.031630

# %%
pca = grid_search.best_estimator_.named_steps['pca']
print(pca.n_components_)
print(pca.explained_variance_ratio_)
componentes = pd.DataFrame(
    pca.components_,
    columns=original_column_names,
    index=[f'PC{i+1}' for i in range(pca.n_components_)]
)

print(componentes)
for i in range(pca.n_components_):
    print(f"\n🔹 PC{i+1}")
    print(componentes.iloc[i].abs().sort_values(ascending=False))
# Out:
# 5
# [0.40108581 0.22937875 0.20211988 0.09440421 0.02911047]
#      temperature_2m (°C)  relative_humidity_2m (%)  surface_pressure (hPa)  \
# PC1             0.261241                 -0.267073               -0.308163
# PC2             0.276168                 -0.064960               -0.208183
# PC3            -0.570072                  0.596969                0.035116
# PC4            -0.022746                 -0.326580                0.889786
# PC5             0.640111                  0.673916                0.258737
#
#      wind_speed_10m (km/h)  wind_direction_10m (°)  wind_speed_100m (km/h)  \
# PC1               0.479759                0.240854                0.407753
# PC2              -0.326654                0.544724               -0.346215
# PC3               0.134273                0.315002                0.312667
# PC4               0.071418                0.225118                0.042940
# PC5               0.122382               -0.083898               -0.110018
#
#      wind_direction_100m (°)  wind_gusts_10m (km/h)
# PC1                 0.252496               0.497258
# PC2                 0.539838              -0.247901
# PC3                 0.314958              -0.056556
# PC4                 0.194091               0.076259
# PC5                 0.026635               0.185261
#
# 🔹 PC1
# wind_gusts_10m (km/h)       0.497258
# wind_speed_10m (km/h)       0.479759
# wind_speed_100m (km/h)      0.407753
# surface_pressure (hPa)      0.308163
# relative_humidity_2m (%)    0.267073
# temperature_2m (°C)         0.261241
# wind_direction_100m (°)     0.252496
# wind_direction_10m (°)      0.240854
# Name: PC1, dtype: float64
#
# 🔹 PC2
# wind_direction_10m (°)      0.544724
# wind_direction_100m (°)     0.539838
# wind_speed_100m (km/h)      0.346215
# wind_speed_10m (km/h)       0.326654
# temperature_2m (°C)         0.276168
# wind_gusts_10m (km/h)       0.247901
# surface_pressure (hPa)      0.208183
# relative_humidity_2m (%)    0.064960
# Name: PC2, dtype: float64
#
# 🔹 PC3
# relative_humidity_2m (%)    0.596969
# temperature_2m (°C)         0.570072
# wind_direction_10m (°)      0.315002
# wind_direction_100m (°)     0.314958
# wind_speed_100m (km/h)      0.312667
# wind_speed_10m (km/h)       0.134273
# wind_gusts_10m (km/h)       0.056556
# surface_pressure (hPa)      0.035116
# Name: PC3, dtype: float64
#
# 🔹 PC4
# surface_pressure (hPa)      0.889786
# relative_humidity_2m (%)    0.326580
# wind_direction_10m (°)      0.225118
# wind_direction_100m (°)     0.194091
# wind_gusts_10m (km/h)       0.076259
# wind_speed_10m (km/h)       0.071418
# wind_speed_100m (km/h)      0.042940
# temperature_2m (°C)         0.022746
# Name: PC4, dtype: float64
#
# 🔹 PC5
# relative_humidity_2m (%)    0.673916
# temperature_2m (°C)         0.640111
# surface_pressure (hPa)      0.258737
# wind_gusts_10m (km/h)       0.185261
# wind_speed_10m (km/h)       0.122382
# wind_speed_100m (km/h)      0.110018
# wind_direction_10m (°)      0.083898
# wind_direction_100m (°)     0.026635
# Name: PC5, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Supongamos que ya tienes tus componentes en un DataFrame
# filas = PCs, columnas = variables originales
componentes = pd.DataFrame({
    'temperature_2m (°C)': [0.261241, 0.276168, 0.570072, 0.022746, 0.640111],
    'relative_humidity_2m (%)': [0.267073, 0.064960, 0.596969, 0.326580, 0.673916],
    'surface_pressure (hPa)': [0.308163, 0.208183, 0.035116, 0.889786, 0.258737],
    'wind_speed_10m (km/h)': [0.479759, 0.326654, 0.134273, 0.071418, 0.122382],
    'wind_direction_10m (°)': [0.240854, 0.544724, 0.315002, 0.225118, 0.083898],
    'wind_speed_100m (km/h)': [0.407753, 0.346215, 0.312667, 0.042940, 0.110018],
    'wind_direction_100m (°)': [0.252496, 0.539838, 0.314958, 0.194091, 0.026635],
    'wind_gusts_10m (km/h)': [0.497258, 0.247901, 0.056556, 0.076259, 0.185261]
}, index=[f'PC{i+1}' for i in range(5)])

# Crear gráfico
fig, axes = plt.subplots(5, 1, figsize=(10, 18))
for i, pc in enumerate(componentes.index):
    ax = axes[i]
    sns.barplot(x=componentes.columns, y=componentes.loc[pc].abs(), palette="viridis", ax=ax)
    ax.set_title(f'Contribución de las variables en {pc}')
    ax.set_ylabel('Valor absoluto')
    ax.set_xticklabels(componentes.columns, rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=componentes.columns, y=componentes.loc[pc].abs(), palette="viridis", ax=ax)
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(componentes.columns, rotation=45, ha='right')
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=componentes.columns, y=componentes.loc[pc].abs(), palette="viridis", ax=ax)
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(componentes.columns, rotation=45, ha='right')
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=componentes.columns, y=componentes.loc[pc].abs(), palette="viridis", ax=ax)
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(componentes.columns, rotation=45, ha='right')
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=componentes.columns, y=componentes.loc[pc].abs(), palette="viridis", ax=ax)
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(componentes.columns, rotation=45, ha='right')
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=componentes.columns, y=componentes.loc[pc].abs(), palette="viridis", ax=ax)
# C:\Users\silvi\AppData\Local\Temp\ipykernel_22844\3148014879.py:25: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(componentes.columns, rotation=45, ha='right')

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# DataFrame con PCs
componentes = pd.DataFrame({
    'temperature_2m (°C)': [0.261241, 0.276168, 0.570072, 0.022746, 0.640111],
    'relative_humidity_2m (%)': [0.267073, 0.064960, 0.596969, 0.326580, 0.673916],
    'surface_pressure (hPa)': [0.308163, 0.208183, 0.035116, 0.889786, 0.258737],
    'wind_speed_10m (km/h)': [0.479759, 0.326654, 0.134273, 0.071418, 0.122382],
    'wind_direction_10m (°)': [0.240854, 0.544724, 0.315002, 0.225118, 0.083898],
    'wind_speed_100m (km/h)': [0.407753, 0.346215, 0.312667, 0.042940, 0.110018],
    'wind_direction_100m (°)': [0.252496, 0.539838, 0.314958, 0.194091, 0.026635],
    'wind_gusts_10m (km/h)': [0.497258, 0.247901, 0.056556, 0.076259, 0.185261]
}, index=[f'PC{i+1}' for i in range(5)])

# Gráfico
fig, axes = plt.subplots(5, 1, figsize=(12, 18))

for i, pc in enumerate(componentes.index):
    ax = axes[i]
    y = componentes.loc[pc].abs()
    x = np.arange(len(componentes.columns))
    ax.bar(x, y, color='teal')
    ax.set_title(f'Contribución de las variables en {pc}', fontsize=12)
    ax.set_ylabel('Valor absoluto', fontsize=10)
    ax.set_xticks(x)
    ax.set_xticklabels(componentes.columns, rotation=45, ha='right', fontsize=10)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# DataFrame con PCs
componentes = pd.DataFrame({
    'temperature_2m (°C)': [0.261241, 0.276168, 0.570072, 0.022746, 0.640111],
    'relative_humidity_2m (%)': [0.267073, 0.064960, 0.596969, 0.326580, 0.673916],
    'surface_pressure (hPa)': [0.308163, 0.208183, 0.035116, 0.889786, 0.258737],
    'wind_speed_10m (km/h)': [0.479759, 0.326654, 0.134273, 0.071418, 0.122382],
    'wind_direction_10m (°)': [0.240854, 0.544724, 0.315002, 0.225118, 0.083898],
    'wind_speed_100m (km/h)': [0.407753, 0.346215, 0.312667, 0.042940, 0.110018],
    'wind_direction_100m (°)': [0.252496, 0.539838, 0.314958, 0.194091, 0.026635],
    'wind_gusts_10m (km/h)': [0.497258, 0.247901, 0.056556, 0.076259, 0.185261]
}, index=[f'PC{i+1}' for i in range(5)])

variables = componentes.columns
n_vars = len(variables)
n_pcs = len(componentes)

x = np.arange(n_vars)  # posiciones de las variables
width = 0.15           # ancho de cada barra

fig, ax = plt.subplots(figsize=(14,6))

# Colores para cada PC
colors = ['teal', 'orange', 'green', 'purple', 'red']

for i, pc in enumerate(componentes.index):
    ax.bar(x + i*width, componentes.loc[pc].abs(), width=width, label=pc, color=colors[i])

# Etiquetas
ax.set_xticks(x + width*2)  # centrar las etiquetas
ax.set_xticklabels(variables, rotation=45, ha='right')
ax.set_ylabel('Valor absoluto de contribución')
ax.set_title('Contribución de las variables por componente principal')
ax.legend(title='Componentes')
plt.tight_layout()
plt.show()

# %%
import joblib

joblib.dump(grid_search.best_estimator_, 'modelo_mlp_pca_fecha.pkl')
# Out:
# ['modelo_mlp_pca_fecha.pkl']
